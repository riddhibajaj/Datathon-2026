# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/Users/riddhibajaj/Documents/VS Code/Projects/Datathon 2026/Access_to_Care_Dataset - Access_to_Care_Dataset.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#                     TOPIC SUBTOPIC  SUBTOPIC_ID                 TAXONOMY  \
# 0  Angina/angina pectoris      NaN          NaN  Cardiovascular diseases
# 1  Angina/angina pectoris      NaN          NaN  Cardiovascular diseases
# 2  Angina/angina pectoris      NaN          NaN  Cardiovascular diseases
# 3  Angina/angina pectoris      NaN          NaN  Cardiovascular diseases
# 4  Angina/angina pectoris      NaN          NaN  Cardiovascular diseases
#
#    TAXONOMY_ID CLASSIFICATION  CLASSIFICATION_ID  GROUP  GROUP_ID  \
# 0           60          Total                  0  Total         1
# 1           60          Total                  0  Total         1
# 2           60          Total                  0  Total         1
# 3           60          Total                  0  Total         1
# 4           60          Total                  0  Total         1
#
#    GROUP_ORDER  ...                 ESTIMATE_TYPE  ESTIMATE_TYPE_ID  \
# 0            1  ...  Percent of population, crude                 1
# 1            1  ...  Percent of population, crude                 1
# 2            1  ...  Percent of population, crude                 1
# 3            1  ...  Percent of population, crude                 1
# 4            1  ...  Percent of population, crude                 1
#
#    TIME_PERIOD TIME_PERIOD_ID  ESTIMATE STANDARD_ERROR  ESTIMATE_LCI  \
# 0         2019            NaN       1.7            NaN           1.5
# 1         2020            NaN       1.5            NaN           1.3
# 2         2021            NaN       1.5            NaN           1.4
# 3         2022            NaN       1.6            NaN           1.5
# 4         2023            NaN       1.6            NaN           1.4
#
#    ESTIMATE_UCI  FLAG                              FOOTNOTE_ID_LIST
# 0           1.9   NaN  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 1           1.6   NaN  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 2           1.7   NaN  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 3           1.8   NaN  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 4           1.8   NaN  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26208 entries, 0 to 26207
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TOPIC              26208 non-null  object
#  1   SUBTOPIC           1404 non-null   object
#  2   SUBTOPIC_ID        1404 non-null   float64
#  3   TAXONOMY           26208 non-null  object
#  4   TAXONOMY_ID        26208 non-null  int64
#  5   CLASSIFICATION     26208 non-null  object
#  6   CLASSIFICATION_ID  26208 non-null  int64
#  7   GROUP              26208 non-null  object
#  8   GROUP_ID           26208 non-null  int64
#  9   GROUP_ORDER        26208 non-null  int64
#  10  SUBGROUP           26208 non-null  object
#  11  SUBGROUP_ID        26208 non-null  int64
#  12  SUBGROUP_ORDER     26208 non-null  int64
#  13  NESTING_LABEL      2016 non-null   object
#  14  NESTING_LABEL_ID   2016 non-null   float64
#  15  ESTIMATE_TYPE      26208 non-null  object
#  16  ESTIMATE_TYPE_ID   26208 non-null  int64
#  17  TIME_PERIOD        26208 non-null  int64
#  18  TIME_PERIOD_ID     0 non-null      float64
#  19  ESTIMATE           23839 non-null  float64
#  20  STANDARD_ERROR     0 non-null      float64
#  21  ESTIMATE_LCI       23633 non-null  float64
#  22  ESTIMATE_UCI       23633 non-null  float64
#  23  FLAG               2599 non-null   object
#  24  FOOTNOTE_ID_LIST   26208 non-null  object
# dtypes: float64(7), int64(8), object(10)
# memory usage: 5.0+ MB
